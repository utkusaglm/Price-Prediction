# %%
import pandas as pd

# %%
df = pd.read_csv('sp500full.csv')

# %%
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume  \
# 0  2009-12-31  24.100000  24.17  23.940001  23.940001  17.312853  25208100
# 1  2010-01-04  24.110001  24.84  24.010000  24.690001  17.855236  59853700
# 2  2010-01-05  24.600000  24.73  24.379999  24.580000  17.775690  45124500
# 3  2010-01-06  24.540001  24.74  24.340000  24.420000  17.659983  35715700
# 4  2010-01-07  24.299999  24.57  24.170000  24.530001  17.739532  31531200
#
#    Name
# 0  CSCO
# 1  CSCO
# 2  CSCO
# 3  CSCO
# 4  CSCO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832640 entries, 0 to 832639
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       832640 non-null  object
#  1   Open       832640 non-null  float64
#  2   High       832640 non-null  float64
#  3   Low        832640 non-null  float64
#  4   Close      832640 non-null  float64
#  5   Adj Close  832640 non-null  float64
#  6   Volume     832640 non-null  int64
#  7   Name       832640 non-null  object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 50.8+ MB

# %%
df['Name'].unique()
# Out:
# array(['CSCO', 'ISRG', 'PRGO', 'DVN', 'MRO', 'BA', 'GILD', 'NLSN', 'EQIX',
#        'MDT', 'QRVO', 'A', 'MO', 'MCHP', 'CDNS', 'CHTR', 'EIX', 'BBY',
#        'HCA', 'AJG', 'DTE', 'C', 'T', 'CF', 'DISH', 'MGM', 'HUM', 'CBOE',
#        'CFG', 'APH', 'MSI', 'FCX', 'ADM', 'LH', 'PKI', 'LNT', 'BAC',
#        'LNC', 'PSX', 'GPN', 'PPG', 'IRM', 'IQV', 'ESS', 'NOV', 'NAVI',
#        'HAL', 'STZ', 'FLS', 'DXC', 'ADI', 'F', 'HOG', 'ADBE', 'ARE', 'CB',
#        'FLR', 'PEP', 'PEG', 'LLY', 'COST', 'REG', 'NWS', 'LLL', 'LOW',
#        'MDLZ', 'FMC', 'AIZ', 'PDCO', 'CERN', 'MET', 'FTV', 'DLR', 'XRAY',
#        'SCG', 'FAST', 'MPC', 'D', 'CA', 'MRK', 'STX', 'NOC', 'BXP', 'KHC',
#        'IPG', 'ALLE', 'ABBV', 'ORCL', 'ECL', 'ETR', 'EBAY', 'IR', 'AMT',
#        'INTU', 'DRE', 'CMA', 'PG', 'CAT', 'MCD', 'MNST', 'AMZN', 'INTC',
#        'PNR', 'GLW', 'BDX', 'KMI', 'PWR', 'APTV', 'EXR', 'HOLX', 'EXPD',
#        'GM', 'SJM', 'OXY', 'RL', 'CCI', 'MMM', 'MOS', 'HSY', 'JNPR',
# ...

# %%
df['Name'].unique().shape
# Out:
# (381,)

# %%
df[df['Name'] == 'IBM']
# Out:
#               Date        Open        High         Low       Close  Adj Close  \
# 466550  2009-12-31  126.586998  127.007645  125.000000  125.143402  82.345871
# 466551  2010-01-04  125.411087  127.122368  125.095604  126.625237  83.320961
# 466552  2010-01-05  125.889099  126.051628  124.378586  125.095604  82.314423
# 466553  2010-01-06  124.933075  125.707458  124.101341  124.282982  81.779747
# 466554  2010-01-07  124.158699  124.521988  123.240921  123.852776  81.496628
# ...            ...         ...         ...         ...         ...        ...
# 468809  2018-12-21  107.552582  110.210327  105.583176  106.061188  89.383278
# 468810  2018-12-24  105.066925  106.118546  102.772469  102.839386  86.668076
# 468811  2018-12-26  103.250481  106.491394  101.281075  106.491394  89.745827
# 468812  2018-12-27  105.152962  108.776291  104.655830  108.776291  91.671440
# 468813  2018-12-28  109.196938  109.751434  107.552582  108.059273  91.067162
#
#           Volume Name
# ...

# %%
ibm =df[df['Name'] == 'IBM']
ibm['Close']
# Out:
# 466550    125.143402
# 466551    126.625237
# 466552    125.095604
# 466553    124.282982
# 466554    123.852776
#              ...
# 468809    106.061188
# 468810    102.839386
# 468811    106.491394
# 468812    108.776291
# 468813    108.059273
# Name: Close, Length: 2264, dtype: float64

# %%
ibm['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Date'].min(), df['Date'].max()
# Out:
# ('2009-12-31', '2018-12-28')

# %%
dates=pd.date_range(df['Date'].min(), df['Date'].max())
dates
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-01', '2010-01-02', '2010-01-03',
#                '2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-09',
#                ...
#                '2018-12-19', '2018-12-20', '2018-12-21', '2018-12-22',
#                '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', length=3285, freq='D')

# %%
close_prices.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2009-12-31 00:00:00, 2010-01-01 00:00:00, 2010-01-02 00:00:00, 2010-01-03 00:00:00, 2010-01-04 00:00:00]

# %%
symbols =df['Name'].unique()

# %%
df2 = pd.DataFrame(data=ibm['Close'].to_numpy(), index = ibm['Date'],columns=['IBM'])

# %%
df2.head()
# Out:
#                    IBM
# Date
# 2009-12-31  125.143402
# 2010-01-04  126.625237
# 2010-01-05  125.095604
# 2010-01-06  124.282982
# 2010-01-07  123.852776

# %%
close_prices = pd.DataFrame(index=dates)

# %%
 df_sym = df[df['Name'] == 'IBM']
 df_sym.head()
# Out:
#               Date        Open        High         Low       Close  Adj Close  \
# 466550  2009-12-31  126.586998  127.007645  125.000000  125.143402  82.345871
# 466551  2010-01-04  125.411087  127.122368  125.095604  126.625237  83.320961
# 466552  2010-01-05  125.889099  126.051628  124.378586  125.095604  82.314423
# 466553  2010-01-06  124.933075  125.707458  124.101341  124.282982  81.779747
# 466554  2010-01-07  124.158699  124.521988  123.240921  123.852776  81.496628
#
#          Volume Name
# 466550  4417676  IBM
# 466551  6438444  IBM
# 466552  7156104  IBM
# 466553  5863144  IBM
# 466554  6109268  IBM

# %%
df_tmp = pd.DataFrame(data=df_sym['Close'].to_numpy(), index = df_sym['Date'],columns=['IBM'])

# %%
df_tmp
# Out:
#                    IBM
# Date
# 2009-12-31  125.143402
# 2010-01-04  126.625237
# 2010-01-05  125.095604
# 2010-01-06  124.282982
# 2010-01-07  123.852776
# ...                ...
# 2018-12-21  106.061188
# 2018-12-24  102.839386
# 2018-12-26  106.491394
# 2018-12-27  108.776291
# 2018-12-28  108.059273
#
# [2264 rows x 1 columns]

# %%
close_prices = pd.DataFrame(index=dates)

# %%
close_prices
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_tmp
# Out:
#                    IBM
# Date
# 2009-12-31  125.143402
# 2010-01-04  126.625237
# 2010-01-05  125.095604
# 2010-01-06  124.282982
# 2010-01-07  123.852776
# ...                ...
# 2018-12-21  106.061188
# 2018-12-24  102.839386
# 2018-12-26  106.491394
# 2018-12-27  108.776291
# 2018-12-28  108.059273
#
# [2264 rows x 1 columns]

# %%
close_prices.index.name ='Date'

# %%
close_prices = pd.DataFrame(index=dates)

# %%
pd.concat([close_prices,df_tmp], axis=1)
# Out:
#                             IBM
# Date
# 2009-12-31 00:00:00         NaN
# 2010-01-01 00:00:00         NaN
# 2010-01-02 00:00:00         NaN
# 2010-01-03 00:00:00         NaN
# 2010-01-04 00:00:00         NaN
# ...                         ...
# 2018-12-21           106.061188
# 2018-12-24           102.839386
# 2018-12-26           106.491394
# 2018-12-27           108.776291
# 2018-12-28           108.059273
#
# [5549 rows x 1 columns]

# %%
close_prices
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
close_prices =close_prices.join(df_tmp)

# %%
close_prices
# Out:
#             IBM
# Date
# 2009-12-31  NaN
# 2010-01-01  NaN
# 2010-01-02  NaN
# 2010-01-03  NaN
# 2010-01-04  NaN
# ...         ...
# 2018-12-24  NaN
# 2018-12-25  NaN
# 2018-12-26  NaN
# 2018-12-27  NaN
# 2018-12-28  NaN
#
# [3285 rows x 1 columns]

# %%
for symbol in symbols:
    df_sym = df[df['Name'] == symbol]
    df_tmp = pd.DataFrame(data=df_sym['Close'].to_numpy(), index = df_sym['Date'],columns=[symbol])
    print(df_tmp)
    close_prices =close_prices.join(df_tmp)
# Out:
#                  CSCO
# Date
# 2009-12-31  23.940001
# 2010-01-04  24.690001
# 2010-01-05  24.580000
# 2010-01-06  24.420000
# 2010-01-07  24.530001
# ...               ...
# 2018-12-21  41.849998
# 2018-12-24  40.279999
# 2018-12-26  42.470001
# 2018-12-27  42.910000
# 2018-12-28  42.770000
#
# [2264 rows x 1 columns]
#                   ISRG
# Date
# 2009-12-31   33.714443
# 2010-01-04   34.307777
# 2010-01-05   34.153332
# 2010-01-06   34.648888
# 2010-01-07   34.518890
# ...                ...
# 2018-12-21  148.673340
# 2018-12-24  144.963333
# 2018-12-26  153.993332
# 2018-12-27  156.233337
# 2018-12-28  157.066666
#
# [2264 rows x 1 columns]
#                  PRGO
# Date
# 2009-12-31  39.830002
# 2010-01-04  40.349998
# 2010-01-05  38.790001
# 2010-01-06  38.299999
# 2010-01-07  37.990002
# ...               ...
# 2018-12-21  37.029999
# 2018-12-24  36.500000
# 2018-12-26  40.700001
# 2018-12-27  39.619999
# 2018-12-28  39.919998
#
# [2264 rows x 1 columns]
# ...

# %%
close_prices['IBM']
# Out:
# 2009-12-31   NaN
# 2010-01-01   NaN
# 2010-01-02   NaN
# 2010-01-03   NaN
# 2010-01-04   NaN
#               ..
# 2018-12-24   NaN
# 2018-12-25   NaN
# 2018-12-26   NaN
# 2018-12-27   NaN
# 2018-12-28   NaN
# Name: IBM, Length: 3285, dtype: float64

# %%
close_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3285 entries, 2009-12-31 00:00:00 to 2018-12-28 00:00:00
# Columns: 381 entries, CSCO to PPL
# dtypes: float64(381)
# memory usage: 9.7+ MB

# %%
close_prices.to_csv('sp500_close.csv')

# %%
# !head sp500_close.csv
# Out:
# ,CSCO,ISRG,PRGO,DVN,MRO,BA,GILD,NLSN,EQIX,MDT,QRVO,A,MO,MCHP,CDNS,CHTR,EIX,BBY,HCA,AJG,DTE,C,T,CF,DISH,MGM,HUM,CBOE,CFG,APH,MSI,FCX,ADM,LH,PKI,LNT,BAC,LNC,PSX,GPN,PPG,IRM,IQV,ESS,NOV,NAVI,HAL,STZ,FLS,DXC,ADI,F,HOG,ADBE,ARE,CB,FLR,PEP,PEG,LLY,COST,REG,NWS,LLL,LOW,MDLZ,FMC,AIZ,PDCO,CERN,MET,FTV,DLR,XRAY,SCG,FAST,MPC,D,CA,MRK,STX,NOC,BXP,KHC,IPG,ALLE,ABBV,ORCL,ECL,ETR,EBAY,IR,AMT,INTU,DRE,CMA,PG,CAT,MCD,MNST,AMZN,INTC,PNR,GLW,BDX,KMI,PWR,APTV,EXR,HOLX,EXPD,GM,SJM,OXY,RL,CCI,MMM,MOS,HSY,JNPR,DHI,ED,ES,ADSK,IP,EXPE,KO,PCAR,PYPL,NEE,LEG,EMR,MSFT,ANSS,CTAS,AME,HP,IT,ACN,EW,FL,CMG,AWK,COO,SHW,HPQ,AMAT,CCL,MLM,AVY,AAP,ATVI,EA,DE,AMD,KLAC,NDAQ,PNC,KMX,BIIB,NVDA,CHRW,ROP,IDXX,EXC,HES,HD,ALB,AON,FDX,DG,HIG,SIG,CMS,COL,CAG,INCY,SCHW,HSIC,AZO,AXP,HPE,DFS,SEE,HRL,FRT,CME,XOM,AMP,AMG,CVX,CMCSA,PCG,CSRA,PNW,ICE,NFX,CTXS,BEN,DISCK,EMN,SBAC,ROK,NRG,NSC,NKE,FIS,MAS,RF,TAP,MAR,CMI,FB,MTD,KR,PLD,IBM,BSX,LKQ,FBHS,ITW,EOG,PVH,KMB,NEM,ANDV,EL,GS,GD,CNP,PM,RE,MCO,CLX,CAH,HRB,DGX,AVB,GE,HII,ALL,ETN,ALGN,NFLX,L
# ...
